# %%
#import library

# %%
#read data from file

data
# Out:
#              Date   Time                                   city state country  \
# 0      10/10/1949  20:30                             san marcos    TX      US
# 1      10/10/1956  21:00                                   edna    TX      US
# 2      10/10/1960  20:00                                kaneohe    HI      US
# 3      10/10/1961  19:00                                bristol    TN      US
# 4      10/10/1965  23:45                                norwalk    CT      US
# 5      10/10/1966  20:00                              pell city    AL      US
# 6      10/10/1966  21:00                               live oak    FL      US
# 7      10/10/1968  13:00                              hawthorne    CA      US
# 8      10/10/1968  19:00                                brevard    NC      US
# 9      10/10/1970  16:00                               bellmore    NY      US
# 10     10/10/1970  19:00                             manchester    KY      US
# ...

# %%
#b (i)
# Out:
# 5161.211309815906

# %%
#b (ii)
# Out:
# light        14268
# triangle      6952
# circle        6650
# fireball      5364
# unknown       5077
# other         4836
# disk          4555
# sphere        4531
# oval          3260
# formation     2112
# cigar         1750
# changing      1709
# flash         1166
# rectangle     1129
# cylinder      1089
# diamond       1006
# chevron        843
# teardrop       633
# egg            632
# cone           278
# cross          214
# delta            7
# pyramid          1
# crescent         1
# hexagon          1
# Name: shape, dtype: int64

# %%
#b (iii)
# Out:
# 1333

# %%
#b (iv)
# Out:
# 2214

# %%
#b (v)
# Out:
# state
# AK      4385.129518
# AL      1308.798692
# AR    107177.831200
# AZ      6086.449232
# CA      2685.325213
# CO      1295.426936
# CT      3305.397237
# DC       235.071429
# DE       798.712291
# FL     13833.210839
# GA      7142.144111
# HI     24935.129630
# IA       855.754533
# ID       873.658640
# IL       812.304176
# IN      2932.651418
# KS      1322.481688
# KY      3771.259605
# LA     11777.326425
# MA      1223.558015
# MD       796.382292
# ME      1142.193543
# MI       999.008487
# MN      1292.338626
# MO      1060.235588
# MS      8386.901235
# MT      2084.521825
# NC      1119.607158
# ND      1046.820896
# NE      1022.000000
# NH      2095.309570
# NJ      5893.242998
# NM      5364.131733
# NV      2918.797500
# NY      2826.604050
# OH      1354.102556
# OK      1122.516184
# OR      1006.023401
# PA      3706.409683
# PR      1048.000000
# RI      2003.815678
# SC      1029.836295
# SD      2582.572581
# TN      1562.364195
# TX      2299.874523
# ...

# %%
# %matplotlib inline #This allows plots to display in the notebook.
# Out:
# Using matplotlib backend: Qt5Agg

# %%
#d (i)

# %%
#b (ii)

# %%
#d (iii)

# %%
#d (iv)
